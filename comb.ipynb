# %%
import pandas as pd

# %%
data = pd.read_csv('/home/kchen/Documents/nsqip_ibd_ic/data/IBD NSQIP Year 5 merged v1.csv')
data.head()
# Out:
#    case.number completion.status date.of.birth  age.at.time.of.surgery  \
# 0     134306.0          Complete    08/01/1963                   57.60
# 1     134314.0          Complete    07/03/1944                   76.69
# 2     134332.0          Complete    08/11/1939                   81.59
# 3     134380.0          Complete    05/02/1993                   27.87
# 4     134415.0          Complete    04/09/1990                   30.95
#
#    gender                  race hispanic.ethnicity  cpt.code  \
# 0  Female                 White                 No     45397
# 1    Male  Unknown/Not Reported                 No     45113
# 2  Female                 White                 No     44204
# 3    Male                 White                 No     44205
# 4  Female  Unknown/Not Reported                 No     45397
#
#                                      cpt.description  \
# 0  Laparoscopy, surgical; proctectomy, combined a...
# 1  Proctectomy, partial, with rectal mucosectomy,...
# ...

# %%
comb4 = pd.read_csv('/home/kchen/Documents/nsqip_ibd_ic/data/data_clean1.csv')
comb4.head()
# Out:
#    case.number  age.at.time.of.surgery  gender                       race  \
# 0     127544.0                   28.82  Female                      White
# 1     127711.0                   24.56  Female                      White
# 2     128513.0                   21.40  Female  Black or African American
# 3     128570.0                   59.18  Female                      White
# 4     128589.0                   37.81  Female                      White
#
#   hispanic.ethnicity  cpt.code in/out-patient.status elective.surgery  \
# 0                 No     44160             Inpatient               No
# 1                 No     44205             Inpatient               No
# 2                 No     44160             Inpatient               No
# 3                 No     44160            Outpatient              Yes
# 4                 No     44160             Inpatient              Yes
#
#                           origin.status  height  ...  \
# ...
